# %% [markdown]
# # Understanding delta_log or Transaction Log

# %%
# df_log = spark.read.format('text').load('abfss://ac7781b8-403d-4f5e-8354-17df61045427@onelake.dfs.fabric.microsoft.com/9943f12b-9887-4c79-b67a-07a542560d2a/Tables/df_delta_employees_tab/_delta_log/00000000000000000000.json')

#df_log = spark.read.format('text').load('abfss://ac7781b8-403d-4f5e-8354-17df61045427@onelake.dfs.fabric.microsoft.com/9943f12b-9887-4c79-b67a-07a542560d2a/Tables/df_delta_employees_tab/_delta_log/00000000000000000001.json')

#df_log = spark.read.format('text').load('abfss://ac7781b8-403d-4f5e-8354-17df61045427@onelake.dfs.fabric.microsoft.com/9943f12b-9887-4c79-b67a-07a542560d2a/Tables/df_delta_employees_tab/_delta_log/00000000000000000002.json')

#df_log = spark.read.format('text').load('abfss://ac7781b8-403d-4f5e-8354-17df61045427@onelake.dfs.fabric.microsoft.com/9943f12b-9887-4c79-b67a-07a542560d2a/Tables/df_delta_employees_tab/_delta_log/00000000000000000003.json')

df_log = spark.read.format('text').load('abfss://ac7781b8-403d-4f5e-8354-17df61045427@onelake.dfs.fabric.microsoft.com/9943f12b-9887-4c79-b67a-07a542560d2a/Tables/df_delta_employees_tab/_delta_log/00000000000000000004.json')
# Out:
# StatementMeta(, 5aa6206c-7388-4cb9-b23a-b6067cae60a0, 39, Finished, Available, Finished)

# %%
df_log.show(truncate=False)
# Out:
# StatementMeta(, 5aa6206c-7388-4cb9-b23a-b6067cae60a0, 40, Finished, Available, Finished)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...
